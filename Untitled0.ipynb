# %% [markdown]
# <a href="https://colab.research.google.com/github/henasannuthi/ML-assignment-1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ab6ae326-a675-4aa2-b7d6-57ce8a4a61a2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ab6ae326-a675-4aa2-b7d6-57ce8a4a61a2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv('winequality-red.csv')

# %%
df.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.tail(3)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6

# %%
df.head(7)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# ...

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %%
import pandas as pd

# Sample DataFrame
data = {'A': [1, 2, None, 4, 5],
        'B': [None, 2, 3, None, 5],
        'C': [1, 2, 3, 4, 5]}
df = pd.DataFrame(data)

# Check for missing values using isnull() or isna()
missing_values = df.isnull()  # or df.isna()

# Count the number of missing values in each column
missing_count = missing_values.sum()

# Display the columns with missing values and their counts
print(missing_count)
# Out:
# A    1
# B    2
# C    0
# dtype: int64

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
missing_values_sum = df.isnull().sum()
print("Sum of missing values in each column:")
print(missing_values_sum)
# Out:
# Sum of missing values in each column:
# A    1
# B    2
# C    0
# dtype: int64

# %%
# Drop rows with missing values
df_dropped = df.dropna()

# Print the DataFrame with rows containing missing values dropped
print("DataFrame with rows containing missing values dropped:")
print(df_dropped)
# Out:
# DataFrame with rows containing missing values dropped:
#      A    B  C
# 1  2.0  2.0  2
# 4  5.0  5.0  5

# %%
import pandas as pd

# Sample DataFrame
data = {'Survived': [0, 1, 1, 0],
        'Pclass': [3, 1, 3, 1],
        'Name': ['John', 'Alice', 'Bob', 'Eve'],
        'Sex': ['male', 'female', 'male', 'female'],
        'Age': [22, 28, 24, 35],
        'Siblings/Spouses Aboard': [1, 0, 1, 0],
        'Parents/Children Aboard': [0, 1, 1, 1],
        'Fare': [7.25, 71.28, 8.05, 53.1]}

df = pd.DataFrame(data)

# Convert specific columns to categorical
categorical_columns = ['Sex', 'Name']  # Add other columns if needed
df[categorical_columns] = df[categorical_columns].astype('category')

# Check the data types after conversion
print(df.dtypes)
# Out:
# Survived                      int64
# Pclass                        int64
# Name                       category
# Sex                        category
# Age                           int64
# Siblings/Spouses Aboard       int64
# Parents/Children Aboard       int64
# Fare                        float64
# dtype: object

# %%
pip install seaborn

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample Titanic dataset
data = {'Survived': [0, 1, 1, 0, 1],
        'Pclass': [3, 1, 3, 1, 2],
        'Age': [22, 38, 26, 35, 28],
        'Fare': [7.25, 71.28, 7.92, 53.1, 13.0],
        'Sex': ['male', 'female', 'female', 'female', 'male']}
df = pd.DataFrame(data)

# Visualization 1: Countplot of Survived vs. Sex
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Survived', hue='Sex')
plt.title('Survived vs. Sex')
plt.show()

# Visualization 2: Histogram of Age
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='Age', bins=20, kde=True)
plt.title('Distribution of Age')
plt.show()

# Visualization 3: Boxplot of Fare by Pclass
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='Pclass', y='Fare')
plt.title('Fare by Passenger Class (Pclass)')
plt.show()

# Visualization 4: Pairplot of numeric variables
sns.pairplot(data=df, hue='Survived', diag_kind='kde')
plt.title('Pairplot of Numeric Variables')
plt.show()

# Visualization 5: Correlation heatmap
correlation_matrix = df.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(data=correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()
# Out:
# <ipython-input-13-88a2955b1a2c>:37: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset (replace 'winequality-red.csv' with your dataset file path)
data = pd.read_csv('winequality-red.csv')

# Data preprocessing (select features and target)
selected_features = ['fixed acidity', 'citric acid', 'residual sugar', 'chlorides']
X = data[selected_features].values
y = data['volatile acidity'].values

# Split the data into training and testing sets
split_ratio = 0.8
split_index = int(split_ratio * len(X))
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# Calculate linear regression coefficients
X_train_b = np.c_[np.ones((X_train.shape[0], 1)), X_train]
w = np.linalg.inv(X_train_b.T.dot(X_train_b)).dot(X_train_b.T).dot(y_train)

# Make predictions on the test data
X_test_b = np.c_[np.ones((X_test.shape[0], 1)), X_test]
y_pred = X_test_b.dot(w)

# Calculate Mean Squared Error (MSE) on Testing Data
mse = np.mean((y_pred - y_test) ** 2)
print("Mean Squared Error (MSE) on Testing Data:", mse)

# Plot the predictions vs. actual values with the regression line
plt.scatter(y_test, y_pred, marker='o', s=30, label='Actual vs. Predicted')
plt.plot(y_test, y_test, color='red', linestyle='--', label='y=x')
plt.xlabel("Actual quality")
plt.ylabel("Predicted quality")
plt.title("Linear Regression Predictions vs. Actual Data")
plt.legend()

# Add the regression line to the plot
#plt.plot(np.unique(y_test), np.poly1d(np.polyfit(y_test, y_pred, 1))(np.unique(y_test)), color='blue', label='Regression Line')

plt.legend()
plt.show()
# Out:
# Mean Squared Error (MSE) on Testing Data: 0.02072210121765216

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

class LogitRegression:
    def __init__(self, learning_rate, iterations):
        self.learning_rate = learning_rate
        self.iterations = iterations


    def sigmoid(self, z):
        return 1 / (1 + np.exp(-z))

    def cost(self, h, y):
        m = len(y)
        return (-1 / m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))

    def gradient_descent(self, X, h, y):
        m = len(y)
        return (1 / m) * np.dot(X.T, (h - y))

    def fit(self, X, y):
        self.weights = np.random.uniform(0, 1, X.shape[1])
        self.loss = []

        for _ in range(self.iterations):
            z = np.dot(X, self.weights)
            h = self.sigmoid(z)
            gradient = self.gradient_descent(X, h, y)
            self.weights -= self.learning_rate * gradient
            cost = self.cost(h, y)
            self.loss.append(cost)

    def predict(self, X):
        z = np.dot(X, self.weights)
        predicted_probabilities = self.sigmoid(z)
        predictions = [1 if p >= 0.5 else 0 for p in predicted_probabilities]
        return predictions

data = pd.read_csv('penguins.csv')


data.fillna(data.mode().iloc[0], inplace=True)

data['species'] = data['species'].astype('category').cat.codes
data['island'] = data['island'].astype('category').cat.codes
data['sex'] = data['sex'].astype('category').cat.codes

for column in ['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']:
    data[column] = (data[column] - data[column].min()) / (data[column].max() - data[column].min())

X = data[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g', 'island', 'sex']].values
y = data['species'].values

split_ratio = 0.8
split_index = int(split_ratio * len(X))
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

learning_rate = 1e-6
iterations = 100000
model = LogitRegression(learning_rate, iterations)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

accuracy = np.mean(y_pred == y_test)
print("Accuracy: {:.2%}".format(accuracy))


plt.plot(range(iterations), model.loss)
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.title("Loss Over Iterations")
plt.show()
# Out:
# Accuracy: 98.55%
